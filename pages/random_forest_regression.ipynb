# %% [markdown]
# <img src="../img/6.png" width="750" height="300"> <img src="../img/7.png" width="750" height="300">

# %% [markdown]
# <img src="../img/8.png" width="750" height="300"> <img src="../img/9.png" width="750" height="300">

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../data/random+forest+regression+dataset.csv", sep=";", header=None)

# %%
df
# Out:
#     0    1
# 0   1  100
# 1   2   80
# 2   3   70
# 3   4   60
# 4   5   50
# 5   6   40
# 6   7   30
# 7   8   20
# 8   9   10
# 9  10    5

# %%
x = df.iloc[:,0].values.reshape(-1,1)
y = df.iloc[:,1].values.reshape(-1,1)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf = RandomForestRegressor(n_estimators=100, random_state= 42) # n_estimators --> 100 tree
rf.fit(x,y)
# Out:
# /home/irem/Desktop/machine_learning/machine_learning/venv/lib/python3.11/site-packages/sklearn/base.py:1351: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestRegressor(random_state=42)

# %%
rf.predict([[7.8]])
# Out:
# array([22.7])

# %%
x_ = np.arange(np.min(x),np.max(x),0.01).reshape(-1,1) # x'in min değerinde max değerine 0.01 adımlarla git.
y_head = rf.predict(x_)

# %%
#visualize
plt.scatter(x,y,color='red')
plt.plot(x_,y_head,color='green')
plt.xlabel("tribun level")
plt.ylabel("ucret")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# random forest decision treeden daha iyi sonuçlar verir.
