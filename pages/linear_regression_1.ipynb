# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
df = '../data/linear_regression_dataset.csv'

# %%
# sep ---> seperator (Noktalı virgül ile ayrılmış dosyayı okur.)
df = pd.read_csv(df, sep=';')

# %%
df
# Out:
#     deneyim   maas
# 0       0.5   2500
# 1       0.0   2250
# 2       1.0   2750
# 3       5.0   8000
# 4       8.0   9000
# 5       4.0   6900
# 6      15.0  20000
# 7       7.0   8500
# 8       3.0   6000
# 9       2.0   3500
# 10     12.0  15000
# 11     10.0  13000
# 12     14.0  18000
# 13      6.0   7500

# %%
plt.scatter(df.deneyim,df.maas)
plt.xlabel("deneyim")
plt.ylabel("maas")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## Line Fit yada Linear Regression

# %% [markdown]
# <img src="../img/1.png" width="600" height="300">  <img src="../img/2.png" width="600" height="300">

# %%
# linear regression 
from sklearn.linear_model import LinearRegression

# %%
# linear regression modeli
linear_reg = LinearRegression()

# %%
x = df.deneyim
y = df.maas
type(x)
# Out:
# pandas.core.series.Series

# %%
# pandas --> numpy
x = df.deneyim.values
y = df.maas.values
type(x)
# Out:
# numpy.ndarray

# %%
x.shape
# Out:
# (14,)

# %%
x = df.deneyim.values.reshape(-1,1)
y = df.maas.values.reshape(-1,1)

# %%
x.shape
# Out:
# (14, 1)

# %%
linear_reg.fit(x,y)
# Out:
# LinearRegression()
