# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../../data/apple.csv")

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# A_id           0
# Size           0
# Weight         0
# Sweetness      0
# Crunchiness    0
# Juiciness      0
# Ripeness       0
# Acidity        0
# Quality        0
# dtype: int64

# %%
df
# Out:
#         A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0        0.0 -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1        1.0 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2        2.0 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3        3.0 -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4        4.0  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
# ...      ...       ...       ...        ...          ...        ...       ...
# 3995  3995.0  0.059386 -1.067408  -3.714549     0.473052   1.697986  2.244055
# 3996  3996.0 -0.293118  1.949253  -0.204020    -0.640196   0.024523 -1.087900
# 3997  3997.0 -2.634515 -2.138247  -2.440461     0.657223   2.199709  4.763859
# 3998  3998.0 -4.008004 -1.779337   2.366397    -0.200329   2.161435  0.214488
# 3999  3999.0  0.278540 -1.715505   0.121217    -1.154075   1.266677 -0.776571
#
#            Acidity Quality
# ...

# %%
df.Quality = [1 if each =="good" else 0 for each in df.Quality]

# %%
df.drop(["A_id"],axis=1,inplace=True)

# %%
df['Size'] = df['Size'].astype(str).str.replace(".","")

df['Weight'] = df['Weight'].astype(str).str.replace(".","")

df['Sweetness'] = df['Sweetness'].astype(str).str.replace(".","")

df['Crunchiness'] = df['Crunchiness'].astype(str).str.replace(".","")

df['Juiciness'] = df['Juiciness'].astype(str).str.replace(".","")

df['Ripeness'] = df['Ripeness'].astype(str).str.replace(".","")

df['Acidity'] = df['Acidity'].astype(str).str.replace(".","")

# %%
df['Size'] = df['Size'].astype(float)
df['Size'] = df['Size'].astype('int64')

df['Weight'] = df['Weight'].astype(float)
df['Weight'] = df['Weight'].astype('int64')

df['Sweetness'] = df['Sweetness'].astype(float)
df['Sweetness'] = df['Sweetness'].astype('int64')

df['Crunchiness'] = df['Crunchiness'].astype(float)
df['Crunchiness'] = df['Crunchiness'].astype('int64')

df['Juiciness'] = df['Juiciness'].astype(float)
df['Juiciness'] = df['Juiciness'].astype('int64')

df['Ripeness'] = df['Ripeness'].astype(float)
df['Ripeness'] = df['Ripeness'].astype('int64')

df['Acidity'] = df['Acidity'].astype(float)
df['Acidity'] = df['Acidity'].astype('int64')

# %%
df
# Out:
#             Size      Weight   Sweetness  Crunchiness   Juiciness    Ripeness  \
# 0    -3970048523 -2512336381  5346329613  -1012008712  1844900361   329839797
# 1    -1195217191 -2839256528  3664058758   1588232309   853285795   867530082
# 2     -292023862 -1351281995 -1738429162   -342615928  2838635512   -38033328
# 3     -657195773 -2271626609  1324873847    -97874716  3637970491 -3413761338
# 4      136421682 -1296611877  -384658206    -55300577  3030874354 -1303849429
# ...          ...         ...         ...          ...         ...         ...
# 3995    59386435 -1067408437 -3714548659    473051652  1697986305  2244054722
# 3996  -293118007  1949252549   -20401993   -640195579    24522626 -1087899732
# 3997 -2634515299  -213824672 -2440461285    657222891   219970859  4763859177
# 3998 -4008003744 -1779337107  2366396966   -200329367  2161435121   214488384
# 3999    27853965 -1715505028   121217251  -1154074758    12666774   -77657147
#
#          Acidity  Quality
# ...

# %%
y = df.Quality.values
x_data = df.drop(["Quality"],axis=1)

# %%
x_data
# Out:
#             Size      Weight   Sweetness  Crunchiness   Juiciness    Ripeness  \
# 0    -3970048523 -2512336381  5346329613  -1012008712  1844900361   329839797
# 1    -1195217191 -2839256528  3664058758   1588232309   853285795   867530082
# 2     -292023862 -1351281995 -1738429162   -342615928  2838635512   -38033328
# 3     -657195773 -2271626609  1324873847    -97874716  3637970491 -3413761338
# 4      136421682 -1296611877  -384658206    -55300577  3030874354 -1303849429
# ...          ...         ...         ...          ...         ...         ...
# 3995    59386435 -1067408437 -3714548659    473051652  1697986305  2244054722
# 3996  -293118007  1949252549   -20401993   -640195579    24522626 -1087899732
# 3997 -2634515299  -213824672 -2440461285    657222891   219970859  4763859177
# 3998 -4008003744 -1779337107  2366396966   -200329367  2161435121   214488384
# 3999    27853965 -1715505028   121217251  -1154074758    12666774   -77657147
#
#          Acidity
# ...

# %%
x =(x_data - np.min(x_data))/(np.max(x_data)-np.min(x_data))

# %%
x
# Out:
#           Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0     0.215391  0.314074   0.846088     0.415643   0.609049  0.506483
# 1     0.403240  0.291943   0.732202     0.591673   0.541919  0.542883
# 2     0.464384  0.392675   0.366466     0.460959   0.676323  0.481579
# 3     0.439663  0.330370   0.573845     0.477528   0.730436  0.253050
# 4     0.493389  0.396376   0.458113     0.480410   0.689337  0.395886
# ...        ...       ...        ...          ...        ...       ...
# 3995  0.488174  0.411893   0.232687     0.516178   0.599103  0.636071
# 3996  0.464310  0.616114   0.482773     0.440814   0.485814  0.410505
# 3997  0.305803  0.469678   0.318940     0.528646   0.499045  0.806656
# 3998  0.212821  0.363697   0.644353     0.470592   0.630478  0.498674
# 3999  0.486039  0.368018   0.492360     0.406026   0.485011  0.478896
#
#        Acidity
# 0     0.450874
# 1     0.435221
# 2     0.661632
# 3     0.537684
# 4     0.518137
# ...        ...
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.33,random_state=42)

# %% [markdown]
# ## Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt = DecisionTreeClassifier()
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
# Doğruluk skoru
print("Decisiontree score: " ,dt.score(x_test,y_test))
# Out:
# Decisiontree score:  0.7742424242424243

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(n_estimators = 100, random_state=1)

# %% [markdown]
# n_estimators--> decision tree sayısı

# %%
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier(random_state=1)

# %%
print("random forest algo result: ", rf.score(x_test,y_test))
# Out:
# random forest algo result:  0.843939393939394
